# %% [markdown]
# # Day 01 — Jupyter Notebook Environment & Python Fundamentals
#
# ## Overview
# This notebook marks the beginning of my daily learning log focusing on **Python for AI and Data Science**. The primary goal of this session is to establish a solid understanding of the development environment and execute basic Python operations.
#
# ## Objectives
# By the end of this session, I aim to:
# - Differentiate between Markdown cells and Code cells in Jupyter.
# - Execute basic Python syntax interactively.
# - Establish a professional standard for documenting code experiments.
#
# ## Tools & Environment
# - **Language:** Python 3.x
# - **Environment:** Anaconda / Jupyter Notebook
#
# ---
#
# ## Experiment Log

# %% [markdown]
# ### Experiment 1: Environment Verification
# Running a simple print statement to verify that the Python kernel is active and responding correctly.

# %% [markdown]
# # Printing a standard output to test the kernel
# print("Hello, Ilham Sepriyadi!")

# %% [markdown]
# > **Observation:** The string output is successfully displayed directly below the cell, confirming that the Python kernel is running smoothly without execution errors.

# %% [markdown]
# ### Experiment 2: Direct Arithmetic Operations
# Testing Jupyter's capability to act as an interactive computational tool (REPL - Read, Evaluate, Print, Loop).

# %%
# Executing basic mathematical operations
print(8 + 9)
# Out:
# 17

# %% [markdown]
# > **Observation:** Python immediately computes and returns the mathematical result. This interactive feedback loop is highly efficient for data science experiments.

# %% [markdown]
# ### Experiment 3: Variable Initialization and Memory Allocation
# Allocating integer values to variables and performing operations on them to test basic memory usage.

# %%
# Initializing variables
a = 892003
b = 1432026

# Computing the sum
total_result = a + b
print(total_result)
# Out:
# 2324029

# %% [markdown]
# > **Observation:** Variables successfully store assigned values for later use. This fundamental concept is crucial for storing datasets or model weights in future machine learning tasks.
#
# ---

# %% [markdown]
# ## Key Insights
# From today's experiments, I learned that Jupyter Notebook's architecture is perfectly suited for analytical workflows. Its ability to combine executable code cells with rich text formatting (Markdown) allows for creating clean, readable, and reproducible technical documentation.
#
# ## Next Steps
# In the upcoming notebook (Day 02), I will dive deeper into Python's core data structures. The focus will be on:
# - Understanding basic Data Types (Numbers, Strings).
# - Performing string manipulation and slicing operations.
