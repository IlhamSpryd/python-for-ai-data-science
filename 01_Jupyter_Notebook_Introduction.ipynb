# %% [markdown]
# # 01 — Jupyter Notebook Introduction for PythonPython Learning Log - Day 01

# %% [markdown]
# ## Overview
# Notebook ini merupakan bagian dari perjalanan belajar **Python AI dan Data Science**.

# %% [markdown]
# ## Objectives
# **Memahami :**
# - Perbedaan markdown cell dan code cell.
# - Cara menjalankan kode Python.
# - Cara mendokumentasikan eksperimen.

# %% [markdown]
# ## Tools
# - Python
# - Jupyter Note

# %% [markdown]
# *Catatan : Notebook ini akan terus diperbarui seiring proses belajar.*

# %% [markdown]
# ## Experiment 1 — Running Python Code

# %% [markdown]
# Pada bagian ini saya mencoba menjalankan kode Python sederhana untuk memastikan environment sudah berjalan dengan baik.

# %%
print("Hello, Python")
# Out:
# Hello, Python

# %% [markdown]
# *“Output berhasil muncul di bawah cell, menandakan kernel Python berjalan dengan baik.”*

# %%
a = 8
b = 10
print(a + b)
# Out:
# 18

# %% [markdown]
# *“Pada eksperimen ini menunjukkan bahwa Python dapat langsung mengeksekusi operasi aritmatika di dalam notebook.”*

# %% [markdown]
# ## Experiment 2 — Simple Arithmetic

# %%
print( 8 + 9)
# Out:
# 17

# %% [markdown]
# *“Python juga dapat digunakan sebagai kalkulator untuk melakukan operasi matematika.”*

# %% [markdown]
# ## Experiment 3 — Using Variables

# %%
a = 892003
b = 1432026
hasil = a + b

print(hasil)
# Out:
# 2324029

# %% [markdown]
# *“Variabel digunakan untuk menyimpan nilai yang dapat digunakan kembali dalam program.”*

# %% [markdown]
# ### Insight
# Dari eksperimen ini saya memahami bahwa Jupyter Notebook memungkinkan kombinasi antara kode dan dokumentasi.
# Kode Python dapat dijalankan secara interaktif sehingga sangat cocok untuk eksperimen data science dan AI.

# %% [markdown]
# ### Next Step
# Pada notebook berikutnya saya akan mempelajari konsep dasar Python yang lebih penting, yaitu:
# - Variable
# - Tipe Data (String, Integer, Float)
# - Operasi pada String
